# %%
import pandas as pd
from sklearn import linear_model
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataGameWonMoreThan1500WithColumnNames.csv")

# %%
df
df = pd.get_dummies(df)
df
# Out:
#       Unnamed: 0  ghostUp  ghostDown  ghostLeft  ghostRight  wallUp  wallDown  \
# 0              0    False      False      False       False    True      True
# 1              1    False      False      False       False    True      True
# 2              2    False      False      False       False    True      True
# 3              3    False      False      False       False   False      True
# 4              4    False      False      False       False    True      True
# ...          ...      ...        ...        ...         ...     ...       ...
# 2168         692    False      False      False       False   False     False
# 2169         693    False      False      False       False   False     False
# 2170         694    False      False      False       False   False     False
# 2171         695    False      False      False       False   False      True
# 2172         696    False      False      False       False    True      True
#
#       wallLeft  wallRight  foodUp  ...  legalPositionUp  legalPositionDown  \
# 0        False      False   False  ...            False              False
# 1        False      False   False  ...            False              False
# 2        False      False   False  ...            False              False
# 3        False      False    True  ...             True              False
# 4        False      False   False  ...            False              False
# ...        ...        ...     ...  ...              ...                ...
# 2168      True       True   False  ...             True               True
# 2169      True       True   False  ...             True               True
# 2170      True       True   False  ...             True               True
# 2171      True      False   False  ...             True              False
# 2172     False      False   False  ...            False              False
#
#       legalPositionULeft  legalPositionRight  pacmanPositionX  \
# 0                   True                True                0
# 1                   True                True                0
# 2                   True                True                0
# 3                   True                True                0
# 4                   True                True                0
# ...                  ...                 ...              ...
# 2168               False               False                1
# 2169               False               False                1
# 2170               False               False                1
# 2171               False                True                1
# 2172                True                True                0
#
#       pacmanPositionY  labelNextAction_East  labelNextAction_North  \
# 0                   1                     0                      0
# 1                   1                     0                      0
# 2                   1                     0                      0
# 3                   1                     0                      0
# 4                   1                     0                      0
# ...               ...                   ...                    ...
# 2168                0                     0                      0
# 2169                0                     0                      0
# 2170                0                     0                      0
# 2171                1                     1                      0
# 2172                1                     1                      0
#
#       labelNextAction_South  labelNextAction_West
# 0                         0                     1
# 1                         0                     1
# 2                         0                     1
# 3                         0                     1
# 4                         0                     1
# ...                     ...                   ...
# 2168                      1                     0
# 2169                      1                     0
# 2170                      1                     0
# 2171                      0                     0
# 2172                      0                     0
#
# [2173 rows x 30 columns]

# %%
corr = df.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(30, 30))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmapInvers = sns.diverging_palette(200, 215, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr[corr > 0.5], mask=mask, cmap=cmap, vmax= 1, center=0.5,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
sns.heatmap(corr[corr < -0.3], mask=mask, cmap=cmap, vmax= 0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

# %%
mostCorrelated = (corr["labelNextAction_East"].sort_values(ascending=False)[corr["labelNextAction_East"] > 0.4]).index
mostCorrelated
# Out:
# Index(['labelNextAction_East', 'foodRight', 'legalPositionRight'], dtype='object')

# %%
mask = np.zeros_like(corr[mostCorrelated], dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 30))

sns.heatmap(corr[mostCorrelated], mask=mask, cmap=cmap, vmax= 1, center=0.5,
            square=True, linewidths=.8, cbar_kws={"shrink": .5}, annot=True)

# %%
XEast = df.drop(["labelNextAction_East", "labelNextAction_South","labelNextAction_West","labelNextAction_North"], axis=1)
XEast = df.drop(df.columns[0])
yEast = df["labelNextAction_East"]
lm = linear_model.LinearRegression()
model = lm.fit(XEast,yEast)
model.score(XEast,yEast)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-1b6460f93853> in <module>
# ----> 1 XEast = df.drop(["Unnamed: 0 ","labelNextAction_East", "labelNextAction_South","labelNextAction_West","labelNextAction_North"], axis=1)
#       2 yEast = df["labelNextAction_East"]
#       3 lm = linear_model.LinearRegression()
#       4 model = lm.fit(XEast,yEast)
#       5 model.score(XEast,yEast)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0 '] not found in axis"

# %%
XEast
# Out:
#       Unnamed: 0  ghostUp  ghostDown  ghostLeft  ghostRight  wallUp  wallDown  \
# 0              0    False      False      False       False    True      True
# 1              1    False      False      False       False    True      True
# 2              2    False      False      False       False    True      True
# 3              3    False      False      False       False   False      True
# 4              4    False      False      False       False    True      True
# ...          ...      ...        ...        ...         ...     ...       ...
# 2168         692    False      False      False       False   False     False
# 2169         693    False      False      False       False   False     False
# 2170         694    False      False      False       False   False     False
# 2171         695    False      False      False       False   False      True
# 2172         696    False      False      False       False    True      True
#
#       wallLeft  wallRight  foodUp  ...  nearestCapsule  legalPositionUp  \
# 0        False      False   False  ...               0            False
# 1        False      False   False  ...               0            False
# 2        False      False   False  ...               0            False
# 3        False      False    True  ...               0             True
# 4        False      False   False  ...               0            False
# ...        ...        ...     ...  ...             ...              ...
# 2168      True       True   False  ...               0             True
# 2169      True       True   False  ...               0             True
# 2170      True       True   False  ...               0             True
# 2171      True      False   False  ...               0             True
# 2172     False      False   False  ...               0            False
#
#       legalPositionDown  legalPositionULeft  legalPositionRight  \
# 0                 False                True                True
# 1                 False                True                True
# 2                 False                True                True
# 3                 False                True                True
# 4                 False                True                True
# ...                 ...                 ...                 ...
# 2168               True               False               False
# 2169               True               False               False
# 2170               True               False               False
# 2171              False               False                True
# 2172              False                True                True
#
#       pacmanPositionX  pacmanPositionY  labelNextAction_North  \
# 0                   0                1                      0
# 1                   0                1                      0
# 2                   0                1                      0
# 3                   0                1                      0
# 4                   0                1                      0
# ...               ...              ...                    ...
# 2168                1                0                      0
# 2169                1                0                      0
# 2170                1                0                      0
# 2171                1                1                      0
# 2172                0                1                      0
#
#       labelNextAction_South  labelNextAction_West
# 0                         0                     1
# 1                         0                     1
# 2                         0                     1
# 3                         0                     1
# 4                         0                     1
# ...                     ...                   ...
# 2168                      1                     0
# 2169                      1                     0
# 2170                      1                     0
# 2171                      0                     0
# 2172                      0                     0
#
# [2173 rows x 29 columns]

# %%
from sklearn.metrics import explained_variance_score

yPred = model.predict(XEast)

explained_variance_score(yEast, yPred)
# Out:
# 0.5501358479960894

# %%
from sklearn.model_selection import train_test_split
lm = linear_model.LinearRegression()



resultValues = []
resultVariance = []
for i in range(0,10) :
    xtrain, xtest, ytrain, ytest = train_test_split(XEast, yEast, test_size=0.2)
    modelCV = lm.fit(xtrain,ytrain)
    #print("taux d'erreur")
    #print(1 - modelCV.score(xtrain,ytrain))
    resultVariance.append(modelCV.score(xtrain,ytrain) - modelCV.score(xtest,ytest))
    resultValues.append(modelCV.score(xtest,ytest))
    if (modelCV.score(xtest,ytest) < 0 ) :
        break
    #1 - modelCV.score(xtest,ytest)
    
print(np.mean(resultValues))
print(np.mean(resultVariance))
# Out:
# 0.5367703609349108
# 0.015558417940113183

# %%
xtrain.mean(axis=0)
# Out:
# Unnamed: 0               267.575949
# ghostUp                    0.000000
# ghostDown                  0.000000
# ghostLeft                  0.000000
# ghostRight                 0.000000
# wallUp                     0.476410
# wallDown                   0.533947
# wallLeft                   0.318182
# wallRight                  0.323936
# foodUp                     0.223820
# foodDown                   0.135213
# foodLeft                   0.168585
# foodRight                  0.162831
# emptyUp                    1.000000
# emptyDown                  1.000000
# emptyLeft                  1.000000
# emptyRight                 1.000000
# nearestFood                0.417146
# nearestGhost               0.040852
# nearestCapsule             0.000000
# legalPositionUp            0.523590
# legalPositionDown          0.466053
# legalPositionULeft         0.681818
# legalPositionRight         0.676064
# pacmanPositionX            0.040852
# pacmanPositionY            0.266398
# labelNextAction_North      0.157652
# labelNextAction_South      0.140391
# labelNextAction_West       0.357307
# dtype: float64
