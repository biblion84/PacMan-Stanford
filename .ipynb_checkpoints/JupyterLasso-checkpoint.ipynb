# %%
import pandas as pd
from sklearn import linear_model
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataGameWonMoreThan1500WithColumnNames.csv")

# %%
df
# Out:
#      Unnamed: 0  ghostUp  ghostDown  ghostLeft  ghostRight  wallUp  wallDown  \
# 0           453    False      False      False       False    True      True
# 1           454    False      False      False       False    True      True
# 2           455    False      False      False       False    True      True
# 3           456    False      False      False       False   False      True
# 4           457    False      False      False       False    True      True
# ..          ...      ...        ...        ...         ...     ...       ...
# 433         899    False      False      False       False    True     False
# 434         900    False      False      False       False    True     False
# 435         901    False      False      False       False    True     False
# 436         902    False      False      False       False   False     False
# 437         903    False      False      False       False   False     False
#
#      wallLeft  wallRight  foodUp  ...  nearestFood  nearestGhost  \
# 0       False      False   False  ...     1.000000      0.066667
# 1       False      False   False  ...     0.500000      0.076923
# 2       False      False   False  ...     0.500000      0.090909
# 3       False      False    True  ...     1.000000      0.142857
# 4       False      False   False  ...     0.500000      0.142857
# ..        ...        ...     ...  ...          ...           ...
# 433     False       True   False  ...     0.500000      0.142857
# 434     False      False   False  ...     0.250000      0.200000
# 435     False       True   False  ...     0.333333      0.200000
# 436     False       True   False  ...     0.500000      0.333333
# 437      True      False   False  ...     1.000000      0.500000
#
#      nearestCapsule  legalPositionUp  legalPositionDown  legalPositionULeft  \
# 0          0.083333            False              False                True
# 1          0.090909            False              False                True
# 2          0.111111            False              False                True
# 3          0.166667             True              False                True
# 4          0.166667            False              False                True
# ..              ...              ...                ...                 ...
# 433        0.000000            False               True                True
# 434        0.000000            False               True                True
# 435        0.000000            False               True                True
# 436        0.000000             True               True                True
# 437        0.000000             True               True               False
#
#      legalPositionRight  pacmanPositionX  pacmanPositionY  labelNextAction
# 0                  True             0.45         0.142857                2
# 1                  True             0.40         0.142857                2
# 2                  True             0.35         0.142857                2
# 3                  True             0.30         0.142857                2
# 4                  True             0.25         0.142857                2
# ..                  ...              ...              ...              ...
# 433               False             0.30         0.714286                2
# 434                True             0.25         0.714286                3
# 435               False             0.30         0.714286                1
# 436               False             0.30         0.571429                1
# 437                True             0.30         0.428571                1
#
# [438 rows x 27 columns]

# %%
df
df = pd.get_dummies(df)
df
# Out:
#      Unnamed: 0  ghostUp  ghostDown  ghostLeft  ghostRight  wallUp  wallDown  \
# 0           453    False      False      False       False    True      True
# 1           454    False      False      False       False    True      True
# 2           455    False      False      False       False    True      True
# 3           456    False      False      False       False   False      True
# 4           457    False      False      False       False    True      True
# ..          ...      ...        ...        ...         ...     ...       ...
# 433         899    False      False      False       False    True     False
# 434         900    False      False      False       False    True     False
# 435         901    False      False      False       False    True     False
# 436         902    False      False      False       False   False     False
# 437         903    False      False      False       False   False     False
#
#      wallLeft  wallRight  foodUp  ...  nearestFood  nearestGhost  \
# 0       False      False   False  ...     1.000000      0.066667
# 1       False      False   False  ...     0.500000      0.076923
# 2       False      False   False  ...     0.500000      0.090909
# 3       False      False    True  ...     1.000000      0.142857
# 4       False      False   False  ...     0.500000      0.142857
# ..        ...        ...     ...  ...          ...           ...
# 433     False       True   False  ...     0.500000      0.142857
# 434     False      False   False  ...     0.250000      0.200000
# 435     False       True   False  ...     0.333333      0.200000
# 436     False       True   False  ...     0.500000      0.333333
# 437      True      False   False  ...     1.000000      0.500000
#
#      nearestCapsule  legalPositionUp  legalPositionDown  legalPositionULeft  \
# 0          0.083333            False              False                True
# 1          0.090909            False              False                True
# 2          0.111111            False              False                True
# 3          0.166667             True              False                True
# 4          0.166667            False              False                True
# ..              ...              ...                ...                 ...
# 433        0.000000            False               True                True
# 434        0.000000            False               True                True
# 435        0.000000            False               True                True
# 436        0.000000             True               True                True
# 437        0.000000             True               True               False
#
#      legalPositionRight  pacmanPositionX  pacmanPositionY  labelNextAction
# 0                  True             0.45         0.142857                2
# 1                  True             0.40         0.142857                2
# 2                  True             0.35         0.142857                2
# 3                  True             0.30         0.142857                2
# 4                  True             0.25         0.142857                2
# ..                  ...              ...              ...              ...
# 433               False             0.30         0.714286                2
# 434                True             0.25         0.714286                3
# 435               False             0.30         0.714286                1
# 436               False             0.30         0.571429                1
# 437                True             0.30         0.428571                1
#
# [438 rows x 27 columns]

# %%
corr = df.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(30, 30))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
cmapInvers = sns.diverging_palette(200, 215, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr[corr > 0.5], mask=mask, cmap=cmap, vmax= 1, center=0.5,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
sns.heatmap(corr[corr < -0.3], mask=mask, cmap=cmap, vmax= 0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

# %%
mostCorrelated = (corr["labelNextAction"].sort_values(ascending=False)[corr["labelNextAction"] > 0.3]).index
mostCorrelated
# Out:
# Index(['labelNextAction', 'legalPositionRight', 'wallUp', 'wallDown',
#        'foodRight'],
#       dtype='object')

# %%
mask = np.zeros_like(corr[mostCorrelated], dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 30))

sns.heatmap(corr[mostCorrelated], mask=mask, cmap=cmap, vmax= 1, center=0.5,
            square=True, linewidths=.8, cbar_kws={"shrink": .5}, annot=True)

# %%
XEast = df.drop([ "labelNextAction"], axis=1)
XEast = XEast.drop(df.columns[0],axis=1)
yEast = df["labelNextAction"]

lm = linear_model.Lasso(0.0005)
model = lm.fit(XEast,yEast)
model.score(XEast,yEast)
# Out:
# 0.4137038607507427

# %%
# from sklearn import preprocessing

# XEast = df.drop(["labelNextAction_East", "labelNextAction_South","labelNextAction_West","labelNextAction_North"], axis=1)
# XEast = XEast.drop(df.columns[0],axis=1)
# yEast = df["labelNextAction_East"]

# XEast = preprocessing.scale(XEast)
# yEast = preprocessing.scale(yEast)

# lm = linear_model.LinearRegression()
# model = lm.fit(XEast,yEast)
# model.score(XEast,yEast)

# %%
XEast
# Out:
#      ghostUp  ghostDown  ghostLeft  ghostRight  wallUp  wallDown  wallLeft  \
# 0      False      False      False       False    True      True     False
# 1      False      False      False       False    True      True     False
# 2      False      False      False       False    True      True     False
# 3      False      False      False       False   False      True     False
# 4      False      False      False       False    True      True     False
# ..       ...        ...        ...         ...     ...       ...       ...
# 433    False      False      False       False    True     False     False
# 434    False      False      False       False    True     False     False
# 435    False      False      False       False    True     False     False
# 436    False      False      False       False   False     False     False
# 437    False      False      False       False   False     False      True
#
#      wallRight  foodUp  foodDown  ...  emptyRight  nearestFood  nearestGhost  \
# 0        False   False     False  ...           1     1.000000      0.066667
# 1        False   False     False  ...           1     0.500000      0.076923
# 2        False   False     False  ...           1     0.500000      0.090909
# 3        False    True     False  ...           1     1.000000      0.142857
# 4        False   False     False  ...           1     0.500000      0.142857
# ..         ...     ...       ...  ...         ...          ...           ...
# 433       True   False     False  ...           1     0.500000      0.142857
# 434      False   False     False  ...           1     0.250000      0.200000
# 435       True   False     False  ...           1     0.333333      0.200000
# 436       True   False     False  ...           1     0.500000      0.333333
# 437      False   False      True  ...           1     1.000000      0.500000
#
#      nearestCapsule  legalPositionUp  legalPositionDown  legalPositionULeft  \
# 0          0.083333            False              False                True
# 1          0.090909            False              False                True
# 2          0.111111            False              False                True
# 3          0.166667             True              False                True
# 4          0.166667            False              False                True
# ..              ...              ...                ...                 ...
# 433        0.000000            False               True                True
# 434        0.000000            False               True                True
# 435        0.000000            False               True                True
# 436        0.000000             True               True                True
# 437        0.000000             True               True               False
#
#      legalPositionRight  pacmanPositionX  pacmanPositionY
# 0                  True             0.45         0.142857
# 1                  True             0.40         0.142857
# 2                  True             0.35         0.142857
# 3                  True             0.30         0.142857
# 4                  True             0.25         0.142857
# ..                  ...              ...              ...
# 433               False             0.30         0.714286
# 434                True             0.25         0.714286
# 435               False             0.30         0.714286
# 436               False             0.30         0.571429
# 437                True             0.30         0.428571
#
# [438 rows x 25 columns]

# %%
from sklearn.metrics import explained_variance_score

yPred = model.predict(XEast)

explained_variance_score(yEast, yPred)
# Out:
# 0.41377858673109336

# %%
from sklearn.model_selection import train_test_split



resultValues = []
resultVariance = []
for i in range(0,10) :
    xtrain, xtest, ytrain, ytest = train_test_split(XEast, yEast, test_size=0.2)
    modelCV = lm.fit(xtrain,ytrain)
    #print("taux d'erreur")
    #print(1 - modelCV.score(xtrain,ytrain))
    resultVariance.append(modelCV.score(xtrain,ytrain) - modelCV.score(xtest,ytest))
    resultValues.append(modelCV.score(xtest,ytest))
    if (modelCV.score(xtest,ytest) < 0 ) :
        break
    #1 - modelCV.score(xtest,ytest)
    
print(np.mean(resultValues))
print(np.mean(resultVariance))
# Out:
# 0.2534816108478035
# 0.025631884992969665

# %%
xtrain.mean(axis=0)
# Out:
# ghostUp               0.000000
# ghostDown             0.000000
# ghostLeft             0.000000
# ghostRight            0.000000
# wallUp                0.480000
# wallDown              0.528571
# wallLeft              0.314286
# wallRight             0.314286
# foodUp                0.254286
# foodDown              0.128571
# foodLeft              0.188571
# foodRight             0.180000
# emptyUp               1.000000
# emptyDown             1.000000
# emptyLeft             1.000000
# emptyRight            1.000000
# nearestFood           0.640806
# nearestGhost          0.326714
# nearestCapsule        0.069132
# legalPositionUp       0.520000
# legalPositionDown     0.471429
# legalPositionULeft    0.685714
# legalPositionRight    0.685714
# pacmanPositionX       0.471286
# pacmanPositionY       0.398367
# dtype: float64

# %%
#Utilisation d'un vrais algorithme de cross-validation
from sklearn.model_selection import cross_validate

reg = linear_model.Lasso()
cv_results = cross_validate(reg, XEast, yEast, cv=10)
cv_results
# Out:
# {'fit_time': array([0.01495814, 0.00797963, 0.00697994, 0.00696659, 0.00498652,
#         0.00399184, 0.00598526, 0.00398874, 0.0069716 , 0.00698256]),
#  'score_time': array([0.00299239, 0.00299096, 0.00398827, 0.00199556, 0.00199485,
#         0.0019927 , 0.00199366, 0.00300312, 0.00299144, 0.0029912 ]),
#  'test_score': array([-0.02775543, -0.07009601, -0.00476068, -0.01079407, -0.00183342,
#         -0.07902936, -0.0129501 , -0.01771496, -0.00824631, -0.05200963])}

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)
pca.fit(xtrain)

plt.plot(pca.explained_variance_ratio_, 'ro-', linewidth=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
pca.components_.shape
components = pca.fit_transform(scaler.fit_transform(df[mostCorrelated]))

# %%
pca.components_[0]
# Out:
# array([-0.48515398, -0.49208754, -0.44285713, -0.47250189, -0.32108408])
